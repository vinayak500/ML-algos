# %%
pip install --upgrade imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\vinay\anaconda3\lib\site-packages (0.10.1)
# Collecting imbalanced-learn
#   Obtaining dependency information for imbalanced-learn from https://files.pythonhosted.org/packages/92/e8/86c36e1b13007ca9c89381adac6c078cfc8fb71841a76c08a3fe3eca91d3/imbalanced_learn-0.12.0-py3-none-any.whl.metadata
#   Downloading imbalanced_learn-0.12.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\vinay\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\vinay\anaconda3\lib\site-packages (from imbalanced-learn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\vinay\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\vinay\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vinay\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Downloading imbalanced_learn-0.12.0-py3-none-any.whl (257 kB)
#    ---------------------------------------- 0.0/257.7 kB ? eta -:--:--
#    ---------------------------------------- 257.7/257.7 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# Successfully installed imbalanced-learn-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Requirement already satisfied: imbalanced-learn in c:\users\vinay\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\vinay\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\vinay\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\vinay\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\vinay\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vinay\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %%
# !pip uninstall scikit-learn imbalanced-learn
# !pip install scikit-learn imbalanced-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
from sklearn.preprocessing import StandardScaler

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints', 'magic04.data', 'magic04.names', 'Untitled.ipynb']

# %%
pd.read_csv('magic04.data')
# Out:
#         28.7967   16.0021  2.6449  0.3918  0.1982   27.7004    22.011  \
# 0       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 1      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 2       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 3       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# 4       51.6240   21.1502  2.9085  0.2420  0.1340   50.8761   43.1887
# ...         ...       ...     ...     ...     ...       ...       ...
# 19014   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19015   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19016   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19017  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19018  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        -8.2027   40.092   81.8828  g
# 0      -9.9574   6.3609  205.2610  g
# 1     -45.2160  76.9600  256.7880  g
# 2      -7.1513  10.4490  116.7370  g
# 3      21.8393   4.6480  356.4620  g
# 4       9.8145   3.6130  238.0980  g
# ...        ...      ...       ... ..
# 19014   2.8766   2.4229  106.8258  h
# 19015  -2.9632  86.7975  247.4560  h
# 19016  -9.4662  30.2987  256.5166  h
# 19017 -63.8389  84.6874  408.3166  h
# 19018  31.4755  52.7310  272.3174  h
#
# [19019 rows x 11 columns]

# %%
cols = ["fLength", "fWidth", "fSize", "fConc", "fConc1", "fAsym", "fM3Long", "fM3Trans", "fAlpha", "fDist", "class"]

# %%
cols
# Out:
# ['fLength',
#  'fWidth',
#  'fSize',
#  'fConc',
#  'fConc1',
#  'fAsym',
#  'fM3Long',
#  'fM3Trans',
#  'fAlpha',
#  'fDist',
#  'class']

# %%
df = pd.read_csv('magic04.data' , names=cols)

# %%
df
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist class
# 0       -8.2027  40.0920   81.8828     g
# 1       -9.9574   6.3609  205.2610     g
# 2      -45.2160  76.9600  256.7880     g
# 3       -7.1513  10.4490  116.7370     g
# 4       21.8393   4.6480  356.4620     g
# ...         ...      ...       ...   ...
# 19015    2.8766   2.4229  106.8258     h
# 19016   -2.9632  86.7975  247.4560     h
# 19017   -9.4662  30.2987  256.5166     h
# 19018  -63.8389  84.6874  408.3166     h
# 19019   31.4755  52.7310  272.3174     h
#
# [19020 rows x 11 columns]

# %%
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
df.sample(5)
# Out:
#         fLength   fWidth   fSize   fConc  fConc1    fAsym   fM3Long  fM3Trans  \
# 4437   109.0430  22.2986  3.1284  0.1964  0.1060  94.4585  105.8000   17.1356
# 10443   63.8426  20.6160  3.0348  0.2870  0.1500  28.5964   66.0377  -14.9429
# 5979    29.5501   7.8658  2.3483  0.6278  0.4058  29.2047   23.4294    7.2589
# 13264   50.2431  32.8921  3.0982  0.1915  0.1048  36.3855   64.3575   25.4578
# 758     92.3723  47.0706  3.0527  0.1949  0.0996  41.6349   84.6040  -24.5420
#
#         fAlpha     fDist class
# 4437    0.6580  261.2200     g
# 10443  11.7311  198.3480     g
# 5979   17.6342  108.7860     g
# 13264  51.3673  254.5042     h
# 758    17.0860  271.1410     g

# %%
df["class"] = (df["class"] == "g").astype(int)

# %%
df
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist  class
# 0       -8.2027  40.0920   81.8828      1
# 1       -9.9574   6.3609  205.2610      1
# 2      -45.2160  76.9600  256.7880      1
# 3       -7.1513  10.4490  116.7370      1
# 4       21.8393   4.6480  356.4620      1
# ...         ...      ...       ...    ...
# 19015    2.8766   2.4229  106.8258      0
# 19016   -2.9632  86.7975  247.4560      0
# 19017   -9.4662  30.2987  256.5166      0
# 19018  -63.8389  84.6874  408.3166      0
# 19019   31.4755  52.7310  272.3174      0
#
# [19020 rows x 11 columns]

# %%
df.sample(10)
# Out:
#        fLength   fWidth   fSize   fConc  fConc1    fAsym  fM3Long  fM3Trans  \
# 16061  26.9187  17.3692  2.7498  0.4678  0.2777 -36.2269 -23.6332   -9.2530
# 6315   55.9818  18.2547  2.7889  0.3512  0.1829  13.2042  62.6131    9.0320
# 8812   59.1921  25.7827  3.3440  0.2319  0.1293  13.1784  31.4371  -19.3714
# 16631  12.0413   3.5265  2.2778  0.7560  0.5032 -12.4717  -3.7598   -4.8523
# 546    41.2937  12.6744  2.6942  0.3458  0.1810 -35.2253 -30.0301    8.7423
# 10345  62.2522  21.1889  3.2210  0.2723  0.1536  41.3721  47.3335   15.5675
# 17037  37.4436   9.9618  2.6615  0.4322  0.2619  12.0305  19.1761    1.0944
# 14888  19.8108  18.5803  2.3454  0.5418  0.3002 -11.4779 -20.7586   16.3058
# 6018   89.5444  25.6436  3.5707  0.1827  0.0963 -62.2558  80.4365   12.4215
# 17311  20.0073  12.8554  2.3570  0.5495  0.2747 -17.4217  -6.0294   -7.7629
#
#         fAlpha     fDist  class
# 16061  73.6034   92.6105      0
# 6315   14.5790  266.7390      1
# 8812    4.6050  222.9310      1
# 16631  73.9574  208.9153      0
# 546     5.1530  174.0520      1
# 10345   3.3750  268.3040      1
# 17037  44.1759  204.1767      0
# 14888  87.5784   96.2807      0
# 6018    2.4590  278.6350      1
# 17311  58.5730  131.9050      0

# %%
df
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist  class
# 0       -8.2027  40.0920   81.8828      1
# 1       -9.9574   6.3609  205.2610      1
# 2      -45.2160  76.9600  256.7880      1
# 3       -7.1513  10.4490  116.7370      1
# 4       21.8393   4.6480  356.4620      1
# ...         ...      ...       ...    ...
# 19015    2.8766   2.4229  106.8258      0
# 19016   -2.9632  86.7975  247.4560      0
# 19017   -9.4662  30.2987  256.5166      0
# 19018  -63.8389  84.6874  408.3166      0
# 19019   31.4755  52.7310  272.3174      0
#
# [19020 rows x 11 columns]

# %%
for label in cols[:-1]:
    plt.hist(df[df["class"]==1][label] , color='blue' , label='gamma' , alpha=0.7 , density=True)
    plt.hist(df[df["class"]==0][label] , color='red' , label='hadron' , alpha=0.7 , density=True)
    plt.title(label)
    plt.ylabel('probablity')
    plt.xlabel(label)
    plt.legend()
    plt.show()

# %%
train , valid , test = np.split(df.sample(frac=1) , [int(0.6*len(df)) , int(0.8 * len(df))])

# %%
df
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist  class
# 0       -8.2027  40.0920   81.8828      1
# 1       -9.9574   6.3609  205.2610      1
# 2      -45.2160  76.9600  256.7880      1
# 3       -7.1513  10.4490  116.7370      1
# 4       21.8393   4.6480  356.4620      1
# ...         ...      ...       ...    ...
# 19015    2.8766   2.4229  106.8258      0
# 19016   -2.9632  86.7975  247.4560      0
# 19017   -9.4662  30.2987  256.5166      0
# 19018  -63.8389  84.6874  408.3166      0
# 19019   31.4755  52.7310  272.3174      0
#
# [19020 rows x 11 columns]

# %%
train , valid , test = np.split(df.sample(frac=1) , [int(0.6*len(df)) , int(0.8 * len(df))])

# %%
df.shape
# Out:
# (19020, 11)

# %%
len(train)
# Out:
# 11412

# %%
len(valid)
# Out:
# 3804

# %%
15216 - 11412
# Out:
# 3804

# %%
len(test)
# Out:
# 3804

# %%
len(train)
# Out:
# 11412

# %%
(df.shape[0] - 11412 )/2
# Out:
# 3804.0

# %%
train
# Out:
#         fLength   fWidth   fSize   fConc  fConc1    fAsym  fM3Long  fM3Trans  \
# 15436   75.6267  16.4543  2.4749  0.5695  0.3132  86.5018 -37.0773   -6.4531
# 11761   36.5729  20.8249  3.0658  0.2682  0.1362   3.7589 -22.4056   16.1421
# 14911   49.7403  23.7094  2.7263  0.2329  0.1192  35.1742 -29.4208   20.3422
# 8438    31.3874  10.1213  2.6042  0.4726  0.2550 -17.6592  10.7738    4.7319
# 6472    17.6798  10.9569  2.2148  0.5366  0.2957  -0.5043   4.9753   -4.8227
# ...         ...      ...     ...     ...     ...      ...      ...       ...
# 5791    35.3385  14.4809  2.5894  0.3887  0.2381  11.7378  30.6075   -5.2554
# 13322   30.0286  12.8014  2.6320  0.3827  0.2019  -1.0485  16.2906   10.4785
# 11946   28.3346  11.8033  2.5539  0.4050  0.2109 -16.7901   7.1239    3.9586
# 5986   100.6070  27.9874  3.3503  0.1567  0.0828 -23.4589  82.4536  -12.9894
# 904     81.5827  22.0786  3.1838  0.2502  0.1287  24.4813  51.1844   14.7843
#
#         fAlpha     fDist  class
# 15436  14.4410  125.6010      0
# 11761   2.3540  162.6390      1
# 14911  34.5820  180.1670      0
# 8438   53.3396   37.0972      1
# 6472   82.0150  180.9830      1
# ...        ...       ...    ...
# 5791   50.4970  131.3360      1
# 13322  62.3642  219.3400      0
# 11946   6.7089  192.1610      1
# 5986    1.2458  312.2200      1
# 904     0.5805  354.8920      1
#
# [11412 rows x 11 columns]

# %%
test
# Out:
#        fLength   fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 7802   81.9918  31.9306  3.7042  0.1184  0.0617   24.4257  73.9395  -16.5316
# 15342  13.0958  10.0499  2.3414  0.8018  0.5308  -12.1347  -7.7397   -9.9359
# 1608   32.2232  10.1951  2.4955  0.3770  0.1965   -8.7485  24.4939    5.1440
# 1334   25.8414  18.4628  2.5927  0.4138  0.2465   10.0019  19.5856  -13.5796
# 7925   32.0070  17.9917  2.9325  0.2897  0.1571   20.4275  23.9430    7.9866
# ...        ...      ...     ...     ...     ...       ...      ...       ...
# 16065  37.5469  11.4984  2.3046  0.5332  0.3233   15.5362  19.1568   -8.7005
# 534    34.9922  18.4430  2.9883  0.3225  0.1628    6.2692  16.2665   12.0407
# 4929   81.7837  22.8309  3.1278  0.3234  0.1643 -102.8170 -36.7461  -11.9116
# 5167   47.4777  18.7244  3.1276  0.2557  0.1338   33.2860  35.3095    9.0855
# 4962   30.9685  13.0649  2.6425  0.4351  0.2335   22.6646 -10.2982  -10.3138
#
#         fAlpha     fDist  class
# 7802    3.5195  241.1600      1
# 15342  88.4759  197.6280      0
# 1608    7.2260  150.4140      1
# 1334   26.1088   63.1770      1
# 7925   16.4720  174.2520      1
# ...        ...       ...    ...
# 16065  18.6822  159.2978      0
# 534     8.1910  215.5270      1
# 4929    0.4470  282.6760      1
# 5167   13.1610  162.9810      1
# 4962   14.7540  158.7670      1
#
# [3804 rows x 11 columns]

# %%
valid
# Out:
#         fLength   fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 7465    20.7843  15.7948  2.5899  0.4910  0.3021   24.2409   11.9971
# 3547    21.9365  11.2057  2.2405  0.5977  0.3649  -14.9529  -19.5206
# 11153   20.9580  12.0301  2.5521  0.5582  0.3240  -19.4771  -14.0151
# 12758  157.6840  74.3316  3.8503  0.1688  0.0915 -111.1920 -138.1510
# 3834    19.6725  15.1829  2.4409  0.4674  0.2844    1.9267  -10.2248
# ...         ...      ...     ...     ...     ...       ...       ...
# 9661    20.8222  11.9473  2.4464  0.5259  0.2737   -4.0191   13.8411
# 11629   44.8409  20.9502  2.8960  0.2757  0.1696   -7.7753  -38.3082
# 851     66.0896  16.8242  2.9413  0.4213  0.2181   14.5258   71.2550
# 238     33.4290  29.8932  2.7792  0.2976  0.1538  -13.7784  -31.4401
# 18620  117.0510  46.0894  3.2980  0.2598  0.1377 -160.4910  -50.8962
#
#        fM3Trans   fAlpha     fDist  class
# 7465     7.5164  16.0930  222.3740      1
# 3547    -6.3874  57.4577   25.4976      1
# 11153   -7.4991   5.2710  197.4610      1
# 12758  -47.3886  49.2403  391.0290      0
# 3834     7.5065   8.6250  161.3040      1
# ...         ...      ...       ...    ...
# 9661    11.3123  63.3878  185.0550      1
# 11629   13.1060   1.0638  171.6850      1
# 851      7.1436   8.2426  220.5490      1
# 238    -25.3331  29.6440   28.8145      1
# 18620   39.2138  40.2750  355.3520      0
#
# [3804 rows x 11 columns]

# %%
df.columns[:-1]
# Out:
# Index(['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 'fAsym', 'fM3Long',
#        'fM3Trans', 'fAlpha', 'fDist'],
#       dtype='object')

# %%
df[df.columns[:-1]]
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist
# 0       -8.2027  40.0920   81.8828
# 1       -9.9574   6.3609  205.2610
# 2      -45.2160  76.9600  256.7880
# 3       -7.1513  10.4490  116.7370
# 4       21.8393   4.6480  356.4620
# ...         ...      ...       ...
# 19015    2.8766   2.4229  106.8258
# 19016   -2.9632  86.7975  247.4560
# 19017   -9.4662  30.2987  256.5166
# 19018  -63.8389  84.6874  408.3166
# 19019   31.4755  52.7310  272.3174
#
# [19020 rows x 10 columns]

# %%
df[df.columns[:-1]].values
# Out:
# array([[ 28.7967,  16.0021,   2.6449, ...,  -8.2027,  40.092 ,  81.8828],
#        [ 31.6036,  11.7235,   2.5185, ...,  -9.9574,   6.3609, 205.261 ],
#        [162.052 , 136.031 ,   4.0612, ..., -45.216 ,  76.96  , 256.788 ],
#        ...,
#        [ 75.4455,  47.5305,   3.4483, ...,  -9.4662,  30.2987, 256.5166],
#        [120.5135,  76.9018,   3.9939, ..., -63.8389,  84.6874, 408.3166],
#        [187.1814,  53.0014,   3.2093, ...,  31.4755,  52.731 , 272.3174]])

# %%
df[df.columns[-1]]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 19015    0
# 19016    0
# 19017    0
# 19018    0
# 19019    0
# Name: class, Length: 19020, dtype: int32

# %%
df[df.columns[-1]].values
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
def scale_dataset(dataframe, oversample=False):
    X = dataframe[dataframe.columns[:-1]].values
    y = dataframe[dataframe.columns[-1]].values

    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    if oversample:
        ros = RandomOverSampler()
        X, y = ros.fit_resample(X, y)

    data = np.hstack((X, np.reshape(y, (-1, 1))))

    return data, X, y

# %%
print(len(df[df['class'] == 1]))
print(len(df[df['class'] == 0]))
# Out:
# 12332
# 6688

# %%
print(len(train[train['class'] == 1]))
print(len(train[train['class'] == 0]))
# Out:
# 7390
# 4022

# %%
train
# Out:
#         fLength   fWidth   fSize   fConc  fConc1    fAsym  fM3Long  fM3Trans  \
# 15436   75.6267  16.4543  2.4749  0.5695  0.3132  86.5018 -37.0773   -6.4531
# 11761   36.5729  20.8249  3.0658  0.2682  0.1362   3.7589 -22.4056   16.1421
# 14911   49.7403  23.7094  2.7263  0.2329  0.1192  35.1742 -29.4208   20.3422
# 8438    31.3874  10.1213  2.6042  0.4726  0.2550 -17.6592  10.7738    4.7319
# 6472    17.6798  10.9569  2.2148  0.5366  0.2957  -0.5043   4.9753   -4.8227
# ...         ...      ...     ...     ...     ...      ...      ...       ...
# 5791    35.3385  14.4809  2.5894  0.3887  0.2381  11.7378  30.6075   -5.2554
# 13322   30.0286  12.8014  2.6320  0.3827  0.2019  -1.0485  16.2906   10.4785
# 11946   28.3346  11.8033  2.5539  0.4050  0.2109 -16.7901   7.1239    3.9586
# 5986   100.6070  27.9874  3.3503  0.1567  0.0828 -23.4589  82.4536  -12.9894
# 904     81.5827  22.0786  3.1838  0.2502  0.1287  24.4813  51.1844   14.7843
#
#         fAlpha     fDist  class
# 15436  14.4410  125.6010      0
# 11761   2.3540  162.6390      1
# 14911  34.5820  180.1670      0
# 8438   53.3396   37.0972      1
# 6472   82.0150  180.9830      1
# ...        ...       ...    ...
# 5791   50.4970  131.3360      1
# 13322  62.3642  219.3400      0
# 11946   6.7089  192.1610      1
# 5986    1.2458  312.2200      1
# 904     0.5805  354.8920      1
#
# [11412 rows x 11 columns]

# %%
train , X_train , y_train = scale_dataset(train , oversample=True)

# %%
len(train)
# Out:
# 14780

# %%
len(X_train)
# Out:
# 14780

# %%
len(y_train)
# Out:
# 14780

# %%
sum(y_train==1)
# Out:
# 7390

# %%
sum(y_train==0)
# Out:
# 7390

# %%
train
# Out:
# array([[ 0.52044894, -0.31654041, -0.74512967, ..., -0.50804712,
#         -0.91546474,  0.        ],
#        [-0.39539825, -0.07880061,  0.49844354, ..., -0.96813685,
#         -0.41857067,  1.        ],
#        [-0.08661072,  0.07810244, -0.21604809, ...,  0.25861685,
#         -0.18341868,  0.        ],
#        ...,
#        [-0.62767483, -0.83201683, -1.02398133, ..., -1.01566842,
#         -0.80991064,  0.        ],
#        [ 2.40590921,  5.2048313 ,  3.10049789, ...,  0.46808766,
#          1.81754658,  0.        ],
#        [-0.54037412, -0.79639883, -1.11552886, ...,  0.99589475,
#          0.57792747,  0.        ]])

# %%
train[0]
# Out:
# array([ 0.52044894, -0.31654041, -0.74512967,  1.03643195,  0.89465213,
#         1.53616933, -0.9322211 , -0.31268367, -0.50804712, -0.91546474,
#         0.        ])

# %%
X_train[0]
# Out:
# array([ 0.52044894, -0.31654041, -0.74512967,  1.03643195,  0.89465213,
#         1.53616933, -0.9322211 , -0.31268367, -0.50804712, -0.91546474])

# %%
y_train[0]
# Out:
# 0

# %%
train
# Out:
# array([[ 0.52044894, -0.31654041, -0.74512967, ..., -0.50804712,
#         -0.91546474,  0.        ],
#        [-0.39539825, -0.07880061,  0.49844354, ..., -0.96813685,
#         -0.41857067,  1.        ],
#        [-0.08661072,  0.07810244, -0.21604809, ...,  0.25861685,
#         -0.18341868,  0.        ],
#        ...,
#        [-0.62767483, -0.83201683, -1.02398133, ..., -1.01566842,
#         -0.80991064,  0.        ],
#        [ 2.40590921,  5.2048313 ,  3.10049789, ...,  0.46808766,
#          1.81754658,  0.        ],
#        [-0.54037412, -0.79639883, -1.11552886, ...,  0.99589475,
#          0.57792747,  0.        ]])

# %%
len(valid)
# Out:
# 3804

# %%
valid
# Out:
#         fLength   fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 7465    20.7843  15.7948  2.5899  0.4910  0.3021   24.2409   11.9971
# 3547    21.9365  11.2057  2.2405  0.5977  0.3649  -14.9529  -19.5206
# 11153   20.9580  12.0301  2.5521  0.5582  0.3240  -19.4771  -14.0151
# 12758  157.6840  74.3316  3.8503  0.1688  0.0915 -111.1920 -138.1510
# 3834    19.6725  15.1829  2.4409  0.4674  0.2844    1.9267  -10.2248
# ...         ...      ...     ...     ...     ...       ...       ...
# 9661    20.8222  11.9473  2.4464  0.5259  0.2737   -4.0191   13.8411
# 11629   44.8409  20.9502  2.8960  0.2757  0.1696   -7.7753  -38.3082
# 851     66.0896  16.8242  2.9413  0.4213  0.2181   14.5258   71.2550
# 238     33.4290  29.8932  2.7792  0.2976  0.1538  -13.7784  -31.4401
# 18620  117.0510  46.0894  3.2980  0.2598  0.1377 -160.4910  -50.8962
#
#        fM3Trans   fAlpha     fDist  class
# 7465     7.5164  16.0930  222.3740      1
# 3547    -6.3874  57.4577   25.4976      1
# 11153   -7.4991   5.2710  197.4610      1
# 12758  -47.3886  49.2403  391.0290      0
# 3834     7.5065   8.6250  161.3040      1
# ...         ...      ...       ...    ...
# 9661    11.3123  63.3878  185.0550      1
# 11629   13.1060   1.0638  171.6850      1
# 851      7.1436   8.2426  220.5490      1
# 238    -25.3331  29.6440   28.8145      1
# 18620   39.2138  40.2750  355.3520      0
#
# [3804 rows x 11 columns]

# %%
len(test)
# Out:
# 3804

# %%
test
# Out:
#        fLength   fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 7802   81.9918  31.9306  3.7042  0.1184  0.0617   24.4257  73.9395  -16.5316
# 15342  13.0958  10.0499  2.3414  0.8018  0.5308  -12.1347  -7.7397   -9.9359
# 1608   32.2232  10.1951  2.4955  0.3770  0.1965   -8.7485  24.4939    5.1440
# 1334   25.8414  18.4628  2.5927  0.4138  0.2465   10.0019  19.5856  -13.5796
# 7925   32.0070  17.9917  2.9325  0.2897  0.1571   20.4275  23.9430    7.9866
# ...        ...      ...     ...     ...     ...       ...      ...       ...
# 16065  37.5469  11.4984  2.3046  0.5332  0.3233   15.5362  19.1568   -8.7005
# 534    34.9922  18.4430  2.9883  0.3225  0.1628    6.2692  16.2665   12.0407
# 4929   81.7837  22.8309  3.1278  0.3234  0.1643 -102.8170 -36.7461  -11.9116
# 5167   47.4777  18.7244  3.1276  0.2557  0.1338   33.2860  35.3095    9.0855
# 4962   30.9685  13.0649  2.6425  0.4351  0.2335   22.6646 -10.2982  -10.3138
#
#         fAlpha     fDist  class
# 7802    3.5195  241.1600      1
# 15342  88.4759  197.6280      0
# 1608    7.2260  150.4140      1
# 1334   26.1088   63.1770      1
# 7925   16.4720  174.2520      1
# ...        ...       ...    ...
# 16065  18.6822  159.2978      0
# 534     8.1910  215.5270      1
# 4929    0.4470  282.6760      1
# 5167   13.1610  162.9810      1
# 4962   14.7540  158.7670      1
#
# [3804 rows x 11 columns]

# %%
valid, X_valid, y_valid = scale_dataset(valid, oversample=False)
test, X_test, y_test = scale_dataset(test, oversample=False)

# %%
valid
# Out:
# array([[-0.77851896, -0.34697796, -0.49919084, ..., -0.44022539,
#          0.37008585,  1.        ],
#        [-0.75069799, -0.59733199, -1.25178894, ...,  1.16409584,
#         -2.22239424,  1.        ],
#        [-0.77432481, -0.55235762, -0.58061101, ..., -0.85995439,
#          0.04202999,  1.        ],
#        ...,
#        [ 0.31542105, -0.29082001,  0.2577152 , ..., -0.74470151,
#          0.34605414,  1.        ],
#        [-0.47320053,  0.422147  , -0.09144379, ...,  0.08534731,
#         -2.1787171 ,  1.        ],
#        [ 1.54593302,  1.30571545,  1.0260373 , ...,  0.49766842,
#          2.12114802,  0.        ]])

# %%
len(valid)
# Out:
# 3804

# %%
X_valid[0]
# Out:
# array([-0.77851896, -0.34697796, -0.49919084,  0.61953236,  0.81569963,
#         0.49198192,  0.03974618,  0.33263062, -0.44022539,  0.37008585])

# %%
y_valid[0]
# Out:
# 1

# %%
valid[0]
# Out:
# array([-0.77851896, -0.34697796, -0.49919084,  0.61953236,  0.81569963,
#         0.49198192,  0.03974618,  0.33263062, -0.44022539,  0.37008585,
#         1.        ])

# %%
len(test)
# Out:
# 3804

# %%
X_test[0]
# Out:
# array([ 0.68459408,  0.54824923,  1.87681371, -1.44370695, -1.39060629,
#         0.46930528,  1.23622589, -0.80380004, -0.92245153,  0.64605009])

# %%
y_test[0]
# Out:
# 1

# %%
test[0]
# Out:
# array([ 0.68459408,  0.54824923,  1.87681371, -1.44370695, -1.39060629,
#         0.46930528,  1.23622589, -0.80380004, -0.92245153,  0.64605009,
#         1.        ])

# %%
len(train)
# Out:
# 14780

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(X_train , y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn_model.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
y_test
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72      1309
#            1       0.85      0.85      0.85      2495
#
#     accuracy                           0.81      3804
#    macro avg       0.79      0.79      0.79      3804
# weighted avg       0.81      0.81      0.81      3804

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model = GaussianNB()
nb_model = nb_model.fit(X_train , y_train)

# %%
y_pred = nb_model.predict(X_test)

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.40      0.50      1309
#            1       0.74      0.89      0.81      2495
#
#     accuracy                           0.72      3804
#    macro avg       0.70      0.64      0.65      3804
# weighted avg       0.71      0.72      0.70      3804
